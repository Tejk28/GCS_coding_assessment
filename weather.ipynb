# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejk28/GCS_coding_assessment/blob/main/weather.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install colorama

# %%
import requests
from colorama import Fore, Style, init

# Initialize colorama for compatibility
init()

# Constants
API_KEY = "45285f4451975d8eaded50e57efebd4c"                 #configured API key
BASE_URL = "http://api.openweathermap.org/data/2.5/weather"
FAVORITES = []

def fetch_weather_data(city_name):
    try:
        params = {"q": city_name, "appid": API_KEY, "units": "metric"}
        response = requests.get(BASE_URL, params=params)
        response.raise_for_status()
        return response.json()
    except requests.exceptions.HTTPError as http_err:
        print(f"{Fore.RED}❌ HTTP error occurred: {http_err}{Style.RESET_ALL}")
    except requests.exceptions.ConnectionError:
        print(f"{Fore.RED}❌ Connection error. Please check your internet.{Style.RESET_ALL}")
    except requests.exceptions.Timeout:
        print(f"{Fore.RED}❌ The request timed out. Try again later.{Style.RESET_ALL}")
    except Exception as err:
        print(f"{Fore.RED}❌ An error occurred: {err}{Style.RESET_ALL}")
    return None

def display_weather(data):
    if data:
        city = data.get("name")
        temp = data["main"]["temp"]
        description = data["weather"][0]["description"]
        humidity = data["main"]["humidity"]
        print(f"Weather in {city}:\n- Temperature: {temp}°C\n- Humidity: {humidity}%\n- Description: {description}")
    else:
        print("No data available.")

def manage_favorites(action, city=None):
    if action == "add":
        if len(FAVORITES) < 3:
            FAVORITES.append(city)
            print(f"✅ City '{city}' added to favorites.")
        else:
            print("❌ Favorites limit reached. Remove a city to add a new one.")
    elif action == "remove":
        if city in FAVORITES:
            FAVORITES.remove(city)
            print(f"✅ City '{city}' removed from favorites.")
        else:
            print(f"❌ City '{city}' not found in favorites.")
    elif action == "list":
        if FAVORITES:
            print(f"{Fore.CYAN}🏙️ Favorite Cities:{Style.RESET_ALL}")
            for city in FAVORITES:
                data = fetch_weather_data(city)
                if data:
                    display_weather(data)
        else:
            print("⚠️ No favorite cities yet.")

def display_weather(data):
    if data:
        city = data.get("name")
        temp = data["main"]["temp"]
        description = data["weather"][0]["description"]
        humidity = data["main"]["humidity"]
        print(f"{Fore.CYAN}Weather in {city}:{Style.RESET_ALL}")
        print(f"- 🌡️ Temperature: {Fore.YELLOW}{temp}°C{Style.RESET_ALL}")
        print(f"- 💧 Humidity: {Fore.YELLOW}{humidity}%{Style.RESET_ALL}")
        print(f"- 📝 Description: {Fore.YELLOW}{description.capitalize()}{Style.RESET_ALL}")
    else:
        print(f"{Fore.RED}No data available.{Style.RESET_ALL}")


def main():
    print("Weather CLI Application\n")
    print("Commands:")
    print("1. Search weather (search)")
    print("2. Add city to favorites (add)")
    print("3. List favorite cities (list)")
    print("4. Remove city from favorites (remove)")
    print("5. Exit (exit)")

    while True:
        command = input("\nEnter a command: ").strip().lower()

        if command == "search":
            city = input("Enter city name: ").strip()
            data = fetch_weather_data(city)
            display_weather(data)
        if command == "add":
           city = input("🏙️ Enter city name to add to favorites: ").strip()
           if city in FAVORITES:
              print(f"⚠️ '{city}' is already in your favorites.")
           else:
              manage_favorites("add", city)
        elif command == "list":
            manage_favorites("list")
        elif command == "remove":
            city = input("Enter city name to remove from favorites: ").strip()
            manage_favorites("remove", city)
        elif command == "exit":
             print("👋 Thank you for using the Weather CLI Application. Stay safe and have a great day!")
             break

        else:
            print("Invalid command. Please try again.")

# Run the application
main()
# Out:
# Weather CLI Application
#
# Commands:
# 1. Search weather (search)
# 2. Add city to favorites (add)
# 3. List favorite cities (list)
# 4. Remove city from favorites (remove)
# 5. Exit (exit)
#
# Enter a command: search
# Enter city name: cerritos
# Weather in Cerritos:
# - 🌡️ Temperature: 13.02°C
# - 💧 Humidity: 67%
# - 📝 Description: Clear sky
# Invalid command. Please try again.
#
# Enter a command: add
# 🏙️ Enter city name to add to favorites: raleigh
# ✅ City 'raleigh' added to favorites.
#
# Enter a command: add
# 🏙️ Enter city name to add to favorites: austin
# ✅ City 'austin' added to favorites.
#
# Enter a command: add
# 🏙️ Enter city name to add to favorites: chicago
# ✅ City 'chicago' added to favorites.
#
# Enter a command: add
# 🏙️ Enter city name to add to favorites: sunnyvale
# ❌ Favorites limit reached. Remove a city to add a new one.
#
# Enter a command: remove
# Enter city name to remove from favorites: chicago
# ✅ City 'chicago' removed from favorites.
#
# ...
